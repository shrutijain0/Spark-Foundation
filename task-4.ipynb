# %% [markdown]
# # ***The Saprks Foundation: TASK-4***

# %% [markdown]
# ### ***- perform ‘Exploratory Data Analysis’ on dataset ‘Global Terrorism’***
# ### ***- As a security/defense analyst, try to find out the hot zone of terrorism.***
# ### ***- What all security issues and insights you can derive by EDA?***

# %% [markdown]
# ### ***IMPORT ALL REQUIRED LIBRARIES***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### ***READ THE CSV FILE***

# %%
df=pd.read_csv("globalterrorismdb_0718dist.csv",encoding='latin',low_memory=False)
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %% [markdown]
# ### ***DATASET INFORMATION AND EDA***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16383 entries, 0 to 16382
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(25), object(54)
# memory usage: 16.9+ MB

# %%
df.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  1.638300e+04  16383.000000  16383.000000  16383.000000  16383.000000
# mean   1.977979e+11   1977.917292      6.199658     15.185558      0.020631
# std    3.256153e+08      3.259416      3.435791      8.957958      0.142150
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.976080e+11   1976.000000      3.000000      7.000000      0.000000
# 50%    1.979040e+11   1979.000000      6.000000     15.000000      0.000000
# 75%    1.980110e+11   1980.000000      9.000000     23.000000      0.000000
# max    1.982060e+11   1986.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  16383.000000  16383.000000  15791.000000  15791.000000  16383.000000
# mean     183.810474      5.539095     27.958121    -28.714743      1.250931
# std      170.937589      3.372897     22.122986     55.957117      0.900881
# min        4.000000      1.000000    -45.867889   -157.818968      1.000000
# 25%       69.000000      2.000000     13.692880    -86.319330      1.000000
# 50%      110.000000      8.000000     35.724533     -6.359509      1.000000
# 75%      217.000000      8.000000     43.291618     10.213439      1.000000
# max      605.000000     12.000000     64.837778    172.636225      5.000000
#
#        ...     ransomamt  ransomamtus    ransompaid  ransompaidus  \
# count  ...  4.140000e+02          1.0  8.600000e+01           1.0
# mean   ...  3.818743e+06      20000.0  1.376880e+06           0.0
# std    ...  4.949925e+07          NaN  4.907209e+06           NaN
# min    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 25%    ...  0.000000e+00      20000.0  0.000000e+00           0.0
# 50%    ...  0.000000e+00      20000.0  7.050000e+04           0.0
# 75%    ...  4.132500e+05      20000.0  7.750000e+05           0.0
# max    ...  1.000000e+09      20000.0  4.100000e+07           0.0
#
#        hostkidoutcome   nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count      636.000000  484.000000  16383.000000  16383.000000  16383.000000
# mean         2.888365    8.371901     -3.737167     -3.693463      0.264543
# std          1.281654   28.492310      4.553044      4.601098      0.660530
# min          2.000000  -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000    1.000000     -9.000000     -9.000000      0.000000
# 50%          2.000000    1.000000      0.000000      0.000000      0.000000
# 75%          4.000000    2.000000      0.000000      0.000000      1.000000
# max          7.000000  215.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  16383.000000
# mean      -2.663859
# std        4.560878
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 81 columns]

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999872 -0.074995 -0.010401 -0.055741 -0.342227
# iyear      0.999872  1.000000 -0.085576 -0.010333 -0.055867 -0.342095
# imonth    -0.074995 -0.085576  1.000000  0.007186  0.015938  0.020663
# iday      -0.010401 -0.010333  0.007186  1.000000 -0.000514  0.028812
# extended  -0.055741 -0.055867  0.015938 -0.000514  1.000000 -0.069697
# ...             ...       ...       ...       ...       ...       ...
# nreleased  0.017818  0.018040 -0.020291 -0.019185  0.005058  0.073599
# INT_LOG   -0.096135 -0.096185  0.003774  0.016041  0.027367  0.210098
# INT_IDEO  -0.099909 -0.099962  0.004403  0.014895  0.035595  0.200390
# INT_MISC  -0.204212 -0.204526  0.045664  0.017350  0.032886  0.390960
# INT_ANY   -0.183257 -0.183338  0.013005  0.021046  0.031860  0.314450
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# eventid   -0.020001 -0.279988  -0.021583     0.113065  ...   0.012262
# iyear     -0.019725 -0.279444  -0.021279     0.113402  ...   0.012647
# imonth    -0.017922 -0.012978  -0.019508    -0.045336  ...  -0.035280
# iday       0.008585  0.016192   0.010976    -0.014280  ...   0.005752
# extended  -0.022562 -0.081167  -0.015054     0.034409  ...  -0.032035
# ...             ...       ...        ...          ...  ...        ...
# nreleased  0.128714  0.146678   0.186331    -0.054500  ...   0.006127
# INT_LOG    0.136990  0.138054   0.110674    -0.004978  ...   0.038525
# INT_IDEO   0.137833  0.132557   0.110844    -0.006232  ...   0.034697
# INT_MISC   0.200248  0.239496   0.157818    -0.057706  ...  -0.016979
# INT_ANY    0.242400  0.226661   0.210242    -0.047554  ...   0.024790
#
#            ransomamtus  ransompaid  ransompaidus  hostkidoutcome  nreleased  \
# eventid            NaN   -0.120377           NaN        0.072135   0.017818
# iyear              NaN   -0.123009           NaN        0.071836   0.018040
# imonth             NaN    0.207296           NaN        0.026075  -0.020291
# iday               NaN    0.009265           NaN        0.067414  -0.019185
# extended           NaN   -0.140023           NaN       -0.095920   0.005058
# ...                ...         ...           ...             ...        ...
# nreleased          NaN   -0.040430           NaN       -0.153938   1.000000
# INT_LOG            NaN   -0.045279           NaN       -0.088904  -0.005228
# INT_IDEO           NaN   -0.040577           NaN       -0.099823  -0.005899
# INT_MISC           NaN    0.019720           NaN       -0.019241   0.022071
# INT_ANY            NaN    0.008184           NaN       -0.095193   0.022310
#
#             INT_LOG  INT_IDEO  INT_MISC   INT_ANY
# eventid   -0.096135 -0.099909 -0.204212 -0.183257
# iyear     -0.096185 -0.099962 -0.204526 -0.183338
# imonth     0.003774  0.004403  0.045664  0.013005
# iday       0.016041  0.014895  0.017350  0.021046
# extended   0.027367  0.035595  0.032886  0.031860
# ...             ...       ...       ...       ...
# nreleased -0.005228 -0.005899  0.022071  0.022310
# INT_LOG    1.000000  0.994698  0.126551  0.809164
# INT_IDEO   0.994698  1.000000  0.152517  0.811485
# INT_MISC   0.126551  0.152517  1.000000  0.392872
# INT_ANY    0.809164  0.811485  0.392872  1.000000
#
# [81 rows x 81 columns]

# %%
df.isnull().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    16362
#               ...
# INT_LOG           0
# INT_IDEO          0
# INT_MISC          0
# INT_ANY           0
# related       15683
# Length: 135, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 786

# %%
df.shape
# Out:
# (16383, 135)

# %% [markdown]
# ### ***USING HISTOGRAM TO REPRESENT RELATIONSHIP BETWEEN ALL FEATURES***

# %%
df.hist(figsize=(50,30))
plt.show()

# %% [markdown]
# ### ***COUNTRIES AFFECTED BY TERRORIST ATTACKS***

# %%
df['country'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(x=df['country_txt'].value_counts()[:20].index,y=df['country_txt'].value_counts()[:20].values)
plt.title('TOP COUNTRIES GOT ATTACKED')
plt.xticks(rotation=70)
plt.xlabel('COUNTRIES')
plt.ylabel('NUMBER TO ATTACKS')
plt.show()

# %% [markdown]
# ### ***REGION AFFECTED BY TERRORIST ATTACKS***

# %%
df['region_txt'].value_counts()
plt.figure(figsize=(20,10))
sns.countplot(x='region_txt',data=df)
plt.xticks(rotation=70)
plt.show()

# %%
df['city'].value_counts()
# Out:
# Belfast           933
# San Salvador      845
# Unknown           810
# Rome              446
# Guatemala City    397
#                  ...
# Toro                1
# Siasi district      1
# Maceo               1
# Cisneros            1
# Mount Gilead        1
# Name: city, Length: 2926, dtype: int64

# %% [markdown]
# ### ***NUMBER OF ATTACKS FROM 1970 TO 1986***

# %%
plt.subplots(figsize=(20,10))
sns.countplot(x='iyear',data=df,palette='tab10')
plt.xticks(rotation=70)
plt.title('TERROR ATTACKS FROM 1970 TO 2017')
plt.show()

# %% [markdown]
# ### ***TYPE OF ATTACK USED BY TERRORISTS***

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df['attacktype1_txt'],order=df['attacktype1_txt'].value_counts().index,palette='rainbow')
plt.xticks(rotation=90)
plt.xlabel('ATTACK TYPE')
plt.ylabel('NUMBER OF ATTACKS')
plt.show()

# %% [markdown]
# ### ***ATTACK TARGETS***

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df['targtype1_txt'],order=df['targtype1_txt'].value_counts().index,palette='flare')
plt.xticks(rotation=90)
plt.xlabel('TARGETS')
plt.ylabel('NUMBER OF TARGETS')
plt.show()

# %% [markdown]
# ### ***NAME OF GROUP ATTACKS TERRORIST***

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df['gname'].value_counts()[:20].index,y=df['gname'].value_counts()[:20].values,palette='pastel')
plt.xticks(rotation=90)
plt.title('TOATAL GROUP ATTACKS')
plt.xlabel('GROUP NAME')
plt.ylabel('TOATAL NUMBER OF ATTACKS')
plt.show()

# %% [markdown]
# ### ***CITIES AFFECTED BY TERRORIST***

# %%
df['city'].value_counts()
plt.figure(figsize=(20,10))
sns.barplot(x=df['city'].value_counts()[:20].index,y=df['city'].value_counts()[:20].values)
plt.title('TOP CITIES GOT ATTACKED')
plt.xticks(rotation=70)
plt.xlabel('CITIES')
plt.ylabel('NUMBER TO ATTACKS')
plt.show()

# %% [markdown]
# ### ***WEAPON USED FOR SUPPORTING THE ATTACK TYPE VISUAL***

# %%
df['weaptype1_txt'].value_counts()
plt.figure(figsize=(20,10))
color=['lightblue','red','lightpink','brown']
sns.barplot(x=df['weaptype1_txt'].value_counts()[:20].index,y=df['weaptype1_txt'].value_counts()[:20].values , palette=color)
plt.title('WEAPON USAGE')
plt.xticks(rotation=70)
plt.xlabel('WEAPON USED')
plt.ylabel('NUMBER OF TIMES')
plt.show()

# %% [markdown]
# # ***OBSERVATION***

# %% [markdown]
# ### ***- EI SALVADOR and UNITED KINGDOM are most attacked countries***
# ### ***- WESTERN EUROPE and CENTRAL AMERICA are most attacked region***
# ### ***- There was growth in terrorist attack form 1977 to 1981***
# ### ***- BOMBING and EXPLOSIVE are most used weapon and attack type b=used by terrorist***
# ### ***- BUSINESS and PRIVATE CITIZEN & PROPERTY were most targeted during terrorist attack***
# ### ***- most number of attacks were done by unknown group or not an group terrorist***
# ### ***- BELLFAST and SAN SALVADOR are the most attacked cities***

# %% [markdown]
# ## ***THANK YOU!!!!***
